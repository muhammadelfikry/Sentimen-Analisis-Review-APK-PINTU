# %%
# !pip install google-play-scraper
# !pip install sastrawi
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.3 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7
# Collecting sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 5.5 MB/s eta 0:00:00
# Installing collected packages: sastrawi
# Successfully installed sastrawi-1.0.1

# %%
from google_play_scraper import app, reviews_all, Sort
from google.colab import files
import pandas as pd
import csv

# %%
scrapview = reviews_all(
    "com.valar.pintu",
    lang="id",
    country="id",
    sort=Sort.MOST_RELEVANT,
    count=15000
)

# %%
app_reviews_df = pd.DataFrame(scrapview)
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  d2242e96-2d98-4e73-a107-72011c8d63a5  Pengguna Google
# 1  73c7d371-4d4d-47e4-9321-80bbf6c241f5  Pengguna Google
# 2  f6fd7a0a-578f-4d7b-bc3f-b82f877e2a67  Pengguna Google
# 3  7ee5925a-ba4b-4acc-b088-4f9a3bbc6566  Pengguna Google
# 4  ec3f0b0a-f13d-48d0-9217-4c1901dbec2a  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  baru Join dan ngerasa sangat membantu untuk pe...      5              7
# 1  Maaf saya harus kasih b1, karena aplikasi ini ...      1              5
# 2  Sebagai pemula di dunia kripto, gue ngerasa Pi...      5             11
# 3  Pintu ini emang aplikasi buat investasi kripto...      5              2
# 4  Min ini kok tiba2 aplikasi nya tdk bisa buka y...      5             93
#
#   reviewCreatedVersion                  at  \
# 0               3.71.0 2025-04-26 04:29:58
# 1               3.71.0 2025-04-26 09:05:17
# 2               3.71.0 2025-04-22 18:44:38
# 3               3.71.0 2025-04-27 08:49:18
# 4               3.68.1 2025-03-03 19:06:42
#
#                                         replyContent           repliedAt  \
# 0  Hi Kak, terimakasih atas review dan komentar p... 2025-04-26 08:05:13
# 1  Hi Kak, kami mohon maaf atas kendala yang Kaka... 2025-04-26 15:14:35
# 2  Hi Kak, terima kasih atas review dan komentar ... 2025-04-22 22:26:49
# 3  Hi Kak, terima kasih atas review dan komentar ... 2025-04-27 16:11:47
# 4  Hi Kak, kami mohon maaf atas kendala yang Kaka... 2025-03-04 10:58:49
#
#   appVersion
# 0     3.71.0
# 1     3.71.0
# 2     3.71.0
# 3     3.71.0
# 4     3.68.1

# %%
print("Data Shape: ", app_reviews_df.shape)
app_reviews_df.to_csv("ulasan_aplikasi.csv", index=False)
# Out:
# Data Shape:  (31010, 11)

# %%
files.download("ulasan_aplikasi.csv")
